# %% [markdown]
# # placement prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
# %matplotlib inline

# %%
df=pd.read_csv('/kaggle/input/placement-data-full-class/Placement_data_full_class.csv')

# %%
df = pd.read_csv('Placement_data_full_class.csv')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ASUS\OneDrive\Desktop\nest\placementprediction

# %%
import os
print("Placement_data_full_class.csv" in os.listdir())
# Out:
# False

# %%
df = pd.read_csv(r'C:\Users\ASUS\Downloads\Placement_data_full_class.csv')

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'knn_placement_model.joblib', 'panda basics', 'placement.ipynb', 'Placement_data_full_class (1).csv']

# %%
df = pd.read_csv('Placement_data_full_class (1).csv')

# %%
df.head(50)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 2       3      M  65.00  Central  68.00  Central      Arts     64.00
# 3       4      M  56.00  Central  52.00  Central   Science     52.00
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5       6      M  55.00   Others  49.80   Others   Science     67.25
# 6       7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7       8      M  82.00  Central  64.00  Central   Science     66.00
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9      10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10     11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11     12      M  69.60  Central  68.40  Central  Commerce     78.30
# 12     13      F  47.00  Central  55.00   Others   Science     65.00
# 13     14      F  77.00  Central  87.00  Central  Commerce     59.00
# 14     15      M  62.00  Central  47.00  Central  Commerce     50.00
# 15     16      F  65.00  Central  75.00  Central  Commerce     69.00
# 16     17      M  63.00  Central  66.20  Central  Commerce     65.60
# 17     18      F  55.00  Central  67.00  Central  Commerce     64.00
# 18     19      F  63.00  Central  66.00  Central  Commerce     64.00
# 19     20      M  60.00   Others  67.00   Others      Arts     70.00
# 20     21      M  62.00   Others  65.00   Others  Commerce     66.00
# 21     22      F  79.00   Others  76.00   Others  Commerce     85.00
# 22     23      F  69.80   Others  60.80   Others   Science     72.23
# 23     24      F  77.40   Others  60.00   Others   Science     64.74
# 24     25      M  76.50   Others  97.70   Others   Science     78.86
# 25     26      F  52.58   Others  54.60  Central  Commerce     50.20
# 26     27      M  71.00   Others  79.00   Others  Commerce     66.00
# 27     28      M  63.00   Others  67.00   Others  Commerce     66.00
# 28     29      M  76.76   Others  76.50   Others  Commerce     67.50
# 29     30      M  62.00  Central  67.00  Central  Commerce     58.00
# 30     31      F  64.00  Central  73.50  Central  Commerce     73.00
# 31     32      F  67.00  Central  53.00  Central   Science     65.00
# 32     33      F  61.00  Central  81.00  Central  Commerce     66.40
# 33     34      F  87.00   Others  65.00   Others   Science     81.00
# 34     35      M  62.00   Others  51.00   Others   Science     52.00
# 35     36      F  69.00  Central  78.00  Central  Commerce     72.00
# 36     37      M  51.00  Central  44.00  Central  Commerce     57.00
# 37     38      F  79.00  Central  76.00  Central   Science     65.60
# 38     39      F  73.00   Others  58.00   Others   Science     66.00
# 39     40      M  81.00   Others  68.00   Others   Science     64.00
# 40     41      F  78.00  Central  77.00   Others  Commerce     80.00
# 41     42      F  74.00   Others  63.16   Others  Commerce     65.00
# 42     43      M  49.00   Others  39.00  Central   Science     65.00
# 43     44      M  87.00   Others  87.00   Others  Commerce     68.00
# 44     45      F  77.00   Others  73.00   Others  Commerce     81.00
# 45     46      F  76.00  Central  64.00  Central   Science     72.00
# 46     47      F  70.89   Others  71.98   Others   Science     65.60
# 47     48      M  63.00  Central  60.00  Central  Commerce     57.00
# 48     49      M  63.00   Others  62.00   Others  Commerce     68.00
# 49     50      F  50.00   Others  37.00   Others      Arts     52.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary
# 0    Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1    Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2   Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3    Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4   Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5    Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6   Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7    Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8   Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9   Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed       NaN
# 10  Comm&Mgmt    Yes    62.00         Mkt&HR  60.85      Placed  260000.0
# 11  Comm&Mgmt    Yes    60.00        Mkt&Fin  63.70      Placed  250000.0
# 12  Comm&Mgmt     No    62.00         Mkt&HR  65.04  Not Placed       NaN
# 13  Comm&Mgmt     No    68.00        Mkt&Fin  68.63      Placed  218000.0
# 14  Comm&Mgmt     No    76.00         Mkt&HR  54.96  Not Placed       NaN
# 15  Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66      Placed  200000.0
# 16  Comm&Mgmt    Yes    60.00        Mkt&Fin  62.54      Placed  300000.0
# 17  Comm&Mgmt     No    60.00        Mkt&Fin  67.28  Not Placed       NaN
# 18  Comm&Mgmt     No    68.00         Mkt&HR  64.08  Not Placed       NaN
# 19  Comm&Mgmt    Yes    50.48        Mkt&Fin  77.89      Placed  236000.0
# 20  Comm&Mgmt     No    50.00         Mkt&HR  56.70      Placed  265000.0
# 21  Comm&Mgmt     No    95.00        Mkt&Fin  69.06      Placed  393000.0
# 22   Sci&Tech     No    55.53         Mkt&HR  68.81      Placed  360000.0
# 23   Sci&Tech    Yes    92.00        Mkt&Fin  63.62      Placed  300000.0
# 24   Sci&Tech     No    97.40        Mkt&Fin  74.01      Placed  360000.0
# 25  Comm&Mgmt    Yes    76.00        Mkt&Fin  65.33  Not Placed       NaN
# 26  Comm&Mgmt    Yes    94.00        Mkt&Fin  57.55      Placed  240000.0
# 27  Comm&Mgmt     No    68.00         Mkt&HR  57.69      Placed  265000.0
# 28  Comm&Mgmt    Yes    73.35        Mkt&Fin  64.15      Placed  350000.0
# 29  Comm&Mgmt     No    77.00        Mkt&Fin  51.29  Not Placed       NaN
# 30  Comm&Mgmt     No    52.00         Mkt&HR  56.70      Placed  250000.0
# 31   Sci&Tech     No    64.00         Mkt&HR  58.32  Not Placed       NaN
# 32  Comm&Mgmt     No    50.89         Mkt&HR  62.21      Placed  278000.0
# 33  Comm&Mgmt    Yes    88.00        Mkt&Fin  72.78      Placed  260000.0
# 34     Others     No    68.44         Mkt&HR  62.77  Not Placed       NaN
# 35  Comm&Mgmt     No    71.00         Mkt&HR  62.74      Placed  300000.0
# 36  Comm&Mgmt     No    64.00        Mkt&Fin  51.45  Not Placed       NaN
# 37   Sci&Tech     No    58.00         Mkt&HR  55.47      Placed  320000.0
# 38  Comm&Mgmt     No    53.70         Mkt&HR  56.86      Placed  240000.0
# 39   Sci&Tech     No    93.00        Mkt&Fin  62.56      Placed  411000.0
# 40  Comm&Mgmt     No    60.00        Mkt&Fin  66.72      Placed  287000.0
# 41  Comm&Mgmt    Yes    65.00         Mkt&HR  69.76  Not Placed       NaN
# 42     Others     No    63.00        Mkt&Fin  51.21  Not Placed       NaN
# 43  Comm&Mgmt     No    95.00         Mkt&HR  62.90      Placed  300000.0
# 44  Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70      Placed  200000.0
# 45   Sci&Tech     No    58.00         Mkt&HR  66.53  Not Placed       NaN
# 46  Comm&Mgmt     No    68.00         Mkt&HR  71.63  Not Placed       NaN
# 47  Comm&Mgmt    Yes    78.00        Mkt&Fin  54.55      Placed  204000.0
# 48  Comm&Mgmt     No    64.00        Mkt&Fin  62.46      Placed  250000.0
# 49     Others     No    65.00         Mkt&HR  56.11  Not Placed       NaN

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    str
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    str
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    str
#  6   hsc_s           215 non-null    str
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    str
#  9   workex          215 non-null    str
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    str
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    str
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), str(8)
# memory usage: 25.3 KB

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.shape
# Out:
# (215, 15)

# %%
sns.distplot(df['salary'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_35932\118205992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['salary'])
# <Axes: xlabel='salary', ylabel='Density'>

# %%
sns.boxplot(df['salary'])
# Out:
# <Axes: ylabel='salary'>

# %%
sns.barplot(x='hsc_s',y='salary',data=df)
# Out:
# <Axes: xlabel='hsc_s', ylabel='salary'>

# %%
sns.barplot(x='status',y='specialisation',data=df)
# Out:
# <Axes: xlabel='status', ylabel='specialisation'>

# %%
sns.barplot(x='workex',y='salary',data=df)
# Out:
# <Axes: xlabel='workex', ylabel='salary'>

# %%
sns.barplot(x='status',y='degree_p',data=df)
# Out:
# <Axes: xlabel='status', ylabel='degree_p'>

# %%
sns.barplot(x='status',y='workex',data=df)
# Out:
# <Axes: xlabel='status', ylabel='workex'>

# %%
plt.scatter(x='salary',y='degree_p',data=df)
plt.xlabel('Salary')
plt.ylabel('Degree percentage')
# Out:
# Text(0, 0.5, 'Degree percentage')

# %%
plt.scatter(x='salary',y='mba_p',data=df)
plt.xlabel('Salary')
plt.ylabel('MBA percentage')
# Out:
# Text(0, 0.5, 'MBA percentage')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['gender']=encoder.fit_transform(df['gender'])
df['ssc_b']=encoder.fit_transform(df['ssc_b'])
df['hsc_b']=encoder.fit_transform(df['hsc_b'])
df['hsc_s']=encoder.fit_transform(df['hsc_s'])
df['degree_t']=encoder.fit_transform(df['degree_t'])
df['workex']=encoder.fit_transform(df['workex'])
df['specialisation']=encoder.fit_transform(df['specialisation'])
df['status']=encoder.fit_transform(df['status'])

# %%
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1  67.00      1  91.00      1      1     58.00         2
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status    salary
# 0         0     55.0               1  58.80       1  270000.0
# 1         1     86.5               0  66.28       1  200000.0
# 2         0     75.0               0  57.80       1  250000.0
# 3         0     66.0               1  59.43       0       NaN
# 4         0     96.8               0  55.50       1  425000.0
# ..      ...      ...             ...    ...     ...       ...
# 210       0     91.0               0  74.49       1  400000.0
# 211       0     74.0               0  53.62       1  275000.0
# 212       1     59.0               0  69.72       1  295000.0
# 213       0     70.0               1  60.23       1  204000.0
# 214       0     89.0               1  60.22       0       NaN
#
# [215 rows x 15 columns]

# %%
df['salary'].mode()
# Out:
# 0    300000.0
# Name: salary, dtype: float64

# %%
#df.replace('\t?', float('nan'), inplace=True)  # Replace '\t?' with NaN


#df['salary'] = pd.to_numeric(df['salary'], errors='coerce')

# Drop rows with missing values
#df.dropna(inplace=True)

# %%
#from fancyimpute import KNN
#knn_imputer = KNN()
#df['salary'] = knn_imputer.fit_transform(df['salary'])
#print(df['salary'])

# %%
#df['salary'] = pd.DataFrame(df['salary'], columns =['salary'])

# %%
#df['salary'] = df['salary'].fillna(df['salary'].mode()[0])

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())

# %%
df.head(50)
# Out:
#     sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0       1       1  67.00      1  91.00      1      1     58.00         2
# 1       2       1  79.33      0  78.33      1      2     77.48         2
# 2       3       1  65.00      0  68.00      0      0     64.00         0
# 3       4       1  56.00      0  52.00      0      2     52.00         2
# 4       5       1  85.80      0  73.60      0      1     73.30         0
# 5       6       1  55.00      1  49.80      1      2     67.25         2
# 6       7       0  46.00      1  49.20      1      1     79.00         0
# 7       8       1  82.00      0  64.00      0      2     66.00         2
# 8       9       1  73.00      0  79.00      0      1     72.00         0
# 9      10       1  58.00      0  70.00      0      1     61.00         0
# 10     11       1  58.00      0  61.00      0      1     60.00         0
# 11     12       1  69.60      0  68.40      0      1     78.30         0
# 12     13       0  47.00      0  55.00      1      2     65.00         0
# 13     14       0  77.00      0  87.00      0      1     59.00         0
# 14     15       1  62.00      0  47.00      0      1     50.00         0
# 15     16       0  65.00      0  75.00      0      1     69.00         0
# 16     17       1  63.00      0  66.20      0      1     65.60         0
# 17     18       0  55.00      0  67.00      0      1     64.00         0
# 18     19       0  63.00      0  66.00      0      1     64.00         0
# 19     20       1  60.00      1  67.00      1      0     70.00         0
# 20     21       1  62.00      1  65.00      1      1     66.00         0
# 21     22       0  79.00      1  76.00      1      1     85.00         0
# 22     23       0  69.80      1  60.80      1      2     72.23         2
# 23     24       0  77.40      1  60.00      1      2     64.74         2
# 24     25       1  76.50      1  97.70      1      2     78.86         2
# 25     26       0  52.58      1  54.60      0      1     50.20         0
# 26     27       1  71.00      1  79.00      1      1     66.00         0
# 27     28       1  63.00      1  67.00      1      1     66.00         0
# 28     29       1  76.76      1  76.50      1      1     67.50         0
# 29     30       1  62.00      0  67.00      0      1     58.00         0
# 30     31       0  64.00      0  73.50      0      1     73.00         0
# 31     32       0  67.00      0  53.00      0      2     65.00         2
# 32     33       0  61.00      0  81.00      0      1     66.40         0
# 33     34       0  87.00      1  65.00      1      2     81.00         0
# 34     35       1  62.00      1  51.00      1      2     52.00         1
# 35     36       0  69.00      0  78.00      0      1     72.00         0
# 36     37       1  51.00      0  44.00      0      1     57.00         0
# 37     38       0  79.00      0  76.00      0      2     65.60         2
# 38     39       0  73.00      1  58.00      1      2     66.00         0
# 39     40       1  81.00      1  68.00      1      2     64.00         2
# 40     41       0  78.00      0  77.00      1      1     80.00         0
# 41     42       0  74.00      1  63.16      1      1     65.00         0
# 42     43       1  49.00      1  39.00      0      2     65.00         1
# 43     44       1  87.00      1  87.00      1      1     68.00         0
# 44     45       0  77.00      1  73.00      1      1     81.00         0
# 45     46       0  76.00      0  64.00      0      2     72.00         2
# 46     47       0  70.89      1  71.98      1      2     65.60         0
# 47     48       1  63.00      0  60.00      0      1     57.00         0
# 48     49       1  63.00      1  62.00      1      1     68.00         0
# 49     50       0  50.00      1  37.00      1      0     52.00         1
#
#     workex  etest_p  specialisation  mba_p  status    salary
# 0        0    55.00               1  58.80       1  270000.0
# 1        1    86.50               0  66.28       1  200000.0
# 2        0    75.00               0  57.80       1  250000.0
# 3        0    66.00               1  59.43       0  265000.0
# 4        0    96.80               0  55.50       1  425000.0
# 5        1    55.00               0  51.58       0  265000.0
# 6        0    74.28               0  53.29       0  265000.0
# 7        1    67.00               0  62.14       1  252000.0
# 8        0    91.34               0  61.29       1  231000.0
# 9        0    54.00               0  52.21       0  265000.0
# 10       1    62.00               1  60.85       1  260000.0
# 11       1    60.00               0  63.70       1  250000.0
# 12       0    62.00               1  65.04       0  265000.0
# 13       0    68.00               0  68.63       1  218000.0
# 14       0    76.00               1  54.96       0  265000.0
# 15       1    72.00               0  64.66       1  200000.0
# 16       1    60.00               0  62.54       1  300000.0
# 17       0    60.00               0  67.28       0  265000.0
# 18       0    68.00               1  64.08       0  265000.0
# 19       1    50.48               0  77.89       1  236000.0
# 20       0    50.00               1  56.70       1  265000.0
# 21       0    95.00               0  69.06       1  393000.0
# 22       0    55.53               1  68.81       1  360000.0
# 23       1    92.00               0  63.62       1  300000.0
# 24       0    97.40               0  74.01       1  360000.0
# 25       1    76.00               0  65.33       0  265000.0
# 26       1    94.00               0  57.55       1  240000.0
# 27       0    68.00               1  57.69       1  265000.0
# 28       1    73.35               0  64.15       1  350000.0
# 29       0    77.00               0  51.29       0  265000.0
# 30       0    52.00               1  56.70       1  250000.0
# 31       0    64.00               1  58.32       0  265000.0
# 32       0    50.89               1  62.21       1  278000.0
# 33       1    88.00               0  72.78       1  260000.0
# 34       0    68.44               1  62.77       0  265000.0
# 35       0    71.00               1  62.74       1  300000.0
# 36       0    64.00               0  51.45       0  265000.0
# 37       0    58.00               1  55.47       1  320000.0
# 38       0    53.70               1  56.86       1  240000.0
# 39       0    93.00               0  62.56       1  411000.0
# 40       0    60.00               0  66.72       1  287000.0
# 41       1    65.00               1  69.76       0  265000.0
# 42       0    63.00               0  51.21       0  265000.0
# 43       0    95.00               1  62.90       1  300000.0
# 44       1    89.00               0  69.70       1  200000.0
# 45       0    58.00               1  66.53       0  265000.0
# 46       0    68.00               1  71.63       0  265000.0
# 47       1    78.00               0  54.55       1  204000.0
# 48       0    64.00               0  62.46       1  250000.0
# 49       0    65.00               1  56.11       0  265000.0

# %%
X=df.drop('status',axis=1)
y=df['status']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
y_pred=knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 y_pred=knn.predict(X_test)
#
# NameError: name 'knn' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. Initialize the KNN model (you can adjust n_neighbors if needed)
knn = KNeighborsClassifier(n_neighbors=5)

# 2. Train the model on your training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix,f1_score, accuracy_score

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        45
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[20  0]
#  [ 0 45]]

# %%
f1_score(y_test,y_pred)
# Out:
# 1.0

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
value=[]
i_val=[]
for i in range(1,50,1):
 rf=RandomForestClassifier(n_estimators=i)
 rf.fit(X_train,y_train)
 y_pred1=rf.predict(X_test)
 value.append(accuracy_score(y_test,y_pred1))
 i_val.append(i)

# %%
max(value)
# Out:
# 1.0

# %%
df1=pd.DataFrame(value,index=i_val,columns=['Values'])
df1.head
# Out:
# <bound method NDFrame.head of       Values
# 1   0.861538
# 2   0.769231
# 3   0.938462
# 4   0.969231
# 5   0.907692
# 6   0.953846
# 7   0.907692
# 8   1.000000
# 9   1.000000
# 10  0.969231
# 11  0.953846
# 12  0.953846
# 13  0.953846
# 14  0.969231
# 15  0.953846
# 16  0.953846
# 17  0.938462
# 18  0.923077
# 19  0.953846
# 20  0.969231
# 21  0.938462
# 22  0.953846
# 23  0.969231
# 24  0.969231
# 25  0.984615
# 26  0.984615
# 27  0.938462
# 28  0.984615
# 29  0.938462
# 30  1.000000
# 31  0.953846
# 32  0.984615
# 33  0.953846
# 34  0.969231
# 35  0.953846
# 36  0.984615
# 37  0.938462
# 38  1.000000
# 39  0.969231
# 40  0.969231
# 41  0.984615
# 42  0.969231
# 43  0.953846
# 44  0.969231
# 45  0.969231
# 46  0.953846
# 47  0.938462
# 48  0.953846
# 49  0.969231>

# %%
rf=RandomForestClassifier(n_estimators=26)
rf.fit(X_train,y_train)
y_pred1=rf.predict(X_test)
print(classification_report(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        20
#            1       0.96      0.98      0.97        45
#
#     accuracy                           0.95        65
#    macro avg       0.95      0.94      0.95        65
# weighted avg       0.95      0.95      0.95        65
#
# 0.9538461538461539

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='gini')
dt.fit(X_train,y_train)
y_pred2=dt.predict(X_test)
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        20
#            1       0.98      1.00      0.99        45
#
#     accuracy                           0.98        65
#    macro avg       0.99      0.97      0.98        65
# weighted avg       0.98      0.98      0.98        65

# %%
confusion_matrix(y_test,y_pred2)
# Out:
# array([[19,  1],
#        [ 0, 45]])

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=2, metric='euclidean')  
classifier.fit(X_train, y_train)
y_pred3=classifier.predict(X_test)
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        45
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65

# %%
confusion_matrix(y_test,y_pred3)
# Out:
# array([[20,  0],
#        [ 0, 45]])

# %%
#sl_no: It stands for "serial number" and refers to a unique identifier assigned to each entry or record in a dataset. It helps in distinguishing and tracking individual data points.

#gender: It represents the gender of an individual, typically categorized as male or female. In the given context, it indicates the gender of a person associated with other parameters.

#ssc_p: It refers to the percentage of marks obtained by a person in their secondary school examination (SSC), such as the 10th grade or equivalent.

#ssc_b: It stands for "secondary school board" and represents the education board or institution where the person completed their secondary school education (e.g., CBSE, ICSE, State Board).

#hsc_p: It indicates the percentage of marks obtained by an individual in their higher secondary examination (HSC), such as the 12th grade or equivalent.

#hsc_b: Similar to ssc_b, hsc_b represents the education board or institution where the person completed their higher secondary education.

#hsc_s: It stands for "higher secondary stream" and denotes the stream or subject specialization chosen by an individual during their higher secondary education (e.g., Science, Commerce, Arts).
#degree_p: It refers to the percentage of marks obtained by a person in their undergraduate degree program, such as a bachelor's degree.

#degree_t: It represents the type of undergraduate degree pursued by an individual (e.g., Science, Commerce, Arts) and provides information about their field of study.

#workex: It is a binary variable that indicates whether an individual has prior work experience or not. It is typically represented as "Yes" or "No."
#etest_p: It denotes the percentage of marks obtained by a person in an employability test, which is often conducted as part of the selection process for job placements or higher education.

#specialisation: In the given context, it refers to the area of specialization chosen by an individual during their postgraduate studies (e.g., Marketing, Finance, Human Resources).

#mba_p: It represents the percentage of marks obtained by an individual in their Master of Business Administration (MBA) program or a similar postgraduate business management degree.

#status: It indicates the employment status of an individual, typically represented as "Placed" or "Not Placed." It signifies whether the person has secured a job placement or not.

#salary: This term represents the salary or income earned by an individual after securing a job placement. It denotes the financial compensation received for their employment.

#These terms are commonly used in the context of  educational and job placement datasets, where various factors and attributes of individuals are recorded for analysis and decision-making purposes.

# %%
import joblib

# This saves your trained knn model to a file named 'knn_placement_model.joblib'
joblib.dump(knn, 'knn_placement_model.joblib')
# Out:
# ['knn_placement_model.joblib']

# %%
import joblib

# Load the saved model back into memory
loaded_knn = joblib.load('knn_placement_model.joblib')

# Now you can instantly make predictions!
# new_predictions = loaded_knn.predict(X_new)

# %%
import os
print("knn_placement_model.joblib" in os.listdir())
# Out:
# True

# %%
import pandas as pd
import numpy as np

# CGPA Category
df['CGPA_Category'] = pd.cut(
    df['CGPA'],
    bins=[0, 6, 7.5, 10],
    labels=['Low', 'Medium', 'High']
)

# IQ Score (Example)
df['IQ_Score'] = (df['CGPA'] * 10) + (df['Internships'] * 5)

# Total Academic Score
df['Academic_Score'] = (
    df['CGPA'] +
    df['Projects'] +
    df['Internships']
)

# Communication Level
df['Communication_Level'] = np.where(
    df['Communication_Skills'] >= 7,
    'Good',
    'Average'
)

# Experience Score
df['Experience_Score'] = (
    df['Internships'] +
    df['Projects'] +
    df['Workshops']
)

# Technical Score
df['Technical_Score'] = (
    df['Programming_Skills'] +
    df['Projects']
)

# Placement Readiness
df['Placement_Readiness'] = (
    df['Academic_Score'] +
    df['Technical_Score']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'CGPA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 6
#       2 import numpy as np
#       3
#       4 # CGPA Category
#       5 df['CGPA_Category'] = pd.cut(
# ----> 6     df['CGPA'],
#       7     bins=[0, 6, 7.5, 10],
#       8     labels=['Low', 'Medium', 'High']
#       9 )
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'CGPA'

# %%
print(df.columns.tolist())
# Out:
# ['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status', 'salary']

# %%
df['Degree_Category'] = pd.cut(
    df['degree_p'],
    bins=[0, 60, 75, 100],
    labels=['Low', 'Medium', 'High']
)

# %%
df['MBA_Category'] = pd.cut(
    df['mba_p'],
    bins=[0, 60, 75, 100],
    labels=['Low', 'Medium', 'High']
)

# %%
import pandas as pd
import numpy as np

# CGPA Category
df['CGPA_Category'] = pd.cut(
    df['CGPA'],
    bins=[0, 6, 7.5, 10],
    labels=['Low', 'Medium', 'High']
)

# IQ Score (Example)
df['IQ_Score'] = (df['CGPA'] * 10) + (df['Internships'] * 5)

# Total Academic Score
df['Academic_Score'] = (
    df['CGPA'] +
    df['Projects'] +
    df['Internships']
)

# Communication Level
df['Communication_Level'] = np.where(
    df['Communication_Skills'] >= 7,
    'Good',
    'Average'
)

# Experience Score
df['Experience_Score'] = (
    df['Internships'] +
    df['Projects'] +
    df['Workshops']
)

# Technical Score
df['Technical_Score'] = (
    df['Programming_Skills'] +
    df['Projects']
)

# Placement Readiness
dfdf['Placement_Readiness'] = (
    df['Academic_Score'] +
    df['Technical_Score']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'CGPA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 6
#       2 import numpy as np
#       3
#       4 # CGPA Category
#       5 df['CGPA_Category'] = pd.cut(
# ----> 6     df['CGPA'],
#       7     bins=[0, 6, 7.5, 10],
#       8     labels=['Low', 'Medium', 'High']
#       9 )
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'CGPA'

# %%
df['CGPA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'CGPA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['CGPA']
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\OneDrive\Desktop\nest\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'CGPA'

# %%
df['Academic_Score'] = (
    df['ssc_p'] +
    df['hsc_p'] +
    df['degree_p'] +
    df['mba_p']
) / 4

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...  mba_p  status    salary  Degree_Category  MBA_Category  \
# 0       0  ...  58.80       1  270000.0              Low           Low
# 1       1  ...  66.28       1  200000.0             High        Medium
# 2       0  ...  57.80       1  250000.0           Medium           Low
# 3       0  ...  59.43       0  265000.0              Low           Low
# 4       0  ...  55.50       1  425000.0           Medium           Low
#
#   Academic_Score Placement_Readiness  Consistency_Score  Academic_Improvement  \
# 0        68.7000            61.85000          72.000000                 -9.00
# 1        75.3550            80.92750          78.380000                 -1.85
# 2        63.7000            69.35000          65.666667                 -1.00
# 3        54.8575            60.42875          53.333333                 -4.00
# 4        72.0500            84.42500          77.566667                -12.50
#
#    MBA_Improvement
# 0             0.80
# 1           -11.20
# 2            -6.20
# 3             7.43
# 4           -17.80
#
# [5 rows x 22 columns]

# %%
df['Placement_Readiness'] = (
    df['Academic_Score'] + df['etest_p']
) / 2

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...  mba_p  status    salary  Degree_Category  MBA_Category  \
# 0       0  ...  58.80       1  270000.0              Low           Low
# 1       1  ...  66.28       1  200000.0             High        Medium
# 2       0  ...  57.80       1  250000.0           Medium           Low
# 3       0  ...  59.43       0  265000.0              Low           Low
# 4       0  ...  55.50       1  425000.0           Medium           Low
#
#   Academic_Score Placement_Readiness  Consistency_Score  Academic_Improvement  \
# 0        68.7000            61.85000          72.000000                 -9.00
# 1        75.3550            80.92750          78.380000                 -1.85
# 2        63.7000            69.35000          65.666667                 -1.00
# 3        54.8575            60.42875          53.333333                 -4.00
# 4        72.0500            84.42500          77.566667                -12.50
#
#    MBA_Improvement
# 0             0.80
# 1           -11.20
# 2            -6.20
# 3             7.43
# 4           -17.80
#
# [5 rows x 22 columns]

# %%
df['Consistency_Score'] = (
    df['ssc_p'] + df['hsc_p'] + df['degree_p']
) / 3

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...  mba_p  status    salary  Degree_Category  MBA_Category  \
# 0       0  ...  58.80       1  270000.0              Low           Low
# 1       1  ...  66.28       1  200000.0             High        Medium
# 2       0  ...  57.80       1  250000.0           Medium           Low
# 3       0  ...  59.43       0  265000.0              Low           Low
# 4       0  ...  55.50       1  425000.0           Medium           Low
#
#   Academic_Score Placement_Readiness  Consistency_Score  Academic_Improvement  \
# 0        68.7000            61.85000          72.000000                 -9.00
# 1        75.3550            80.92750          78.380000                 -1.85
# 2        63.7000            69.35000          65.666667                 -1.00
# 3        54.8575            60.42875          53.333333                 -4.00
# 4        72.0500            84.42500          77.566667                -12.50
#
#    MBA_Improvement
# 0             0.80
# 1           -11.20
# 2            -6.20
# 3             7.43
# 4           -17.80
#
# [5 rows x 22 columns]

# %%
df['Academic_Improvement'] = df['degree_p'] - df['ssc_p']

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...  mba_p  status    salary  Degree_Category  MBA_Category  \
# 0       0  ...  58.80       1  270000.0              Low           Low
# 1       1  ...  66.28       1  200000.0             High        Medium
# 2       0  ...  57.80       1  250000.0           Medium           Low
# 3       0  ...  59.43       0  265000.0              Low           Low
# 4       0  ...  55.50       1  425000.0           Medium           Low
#
#   Academic_Score Placement_Readiness  Consistency_Score  Academic_Improvement  \
# 0        68.7000            61.85000          72.000000                 -9.00
# 1        75.3550            80.92750          78.380000                 -1.85
# 2        63.7000            69.35000          65.666667                 -1.00
# 3        54.8575            60.42875          53.333333                 -4.00
# 4        72.0500            84.42500          77.566667                -12.50
#
#    MBA_Improvement
# 0             0.80
# 1           -11.20
# 2            -6.20
# 3             7.43
# 4           -17.80
#
# [5 rows x 22 columns]

# %%
df['MBA_Improvement'] = df['mba_p'] - df['degree_p']

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...  mba_p  status    salary  Degree_Category  MBA_Category  \
# 0       0  ...  58.80       1  270000.0              Low           Low
# 1       1  ...  66.28       1  200000.0             High        Medium
# 2       0  ...  57.80       1  250000.0           Medium           Low
# 3       0  ...  59.43       0  265000.0              Low           Low
# 4       0  ...  55.50       1  425000.0           Medium           Low
#
#   Academic_Score Placement_Readiness  Consistency_Score  Academic_Improvement  \
# 0        68.7000            61.85000          72.000000                 -9.00
# 1        75.3550            80.92750          78.380000                 -1.85
# 2        63.7000            69.35000          65.666667                 -1.00
# 3        54.8575            60.42875          53.333333                 -4.00
# 4        72.0500            84.42500          77.566667                -12.50
#
#    MBA_Improvement
# 0             0.80
# 1           -11.20
# 2            -6.20
# 3             7.43
# 4           -17.80
#
# [5 rows x 22 columns]

# %%
df['WorkEx_Flag'] = df['workex'].map({'Yes': 1, 'No': 0})

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...    salary  Degree_Category  MBA_Category  Academic_Score  \
# 0       0  ...  270000.0              Low           Low         68.7000
# 1       1  ...  200000.0             High        Medium         75.3550
# 2       0  ...  250000.0           Medium           Low         63.7000
# 3       0  ...  265000.0              Low           Low         54.8575
# 4       0  ...  425000.0           Medium           Low         72.0500
#
#    Placement_Readiness Consistency_Score Academic_Improvement  \
# 0             61.85000         72.000000                -9.00
# 1             80.92750         78.380000                -1.85
# 2             69.35000         65.666667                -1.00
# 3             60.42875         53.333333                -4.00
# 4             84.42500         77.566667               -12.50
#
#    MBA_Improvement  WorkEx_Flag  Test_Performance
# 0             0.80          NaN          0.800582
# 1           -11.20          NaN          1.147900
# 2            -6.20          NaN          1.177394
# 3             7.43          NaN          1.203117
# 4           -17.80          NaN          1.343511
#
# [5 rows x 24 columns]

# %%
df['Test_Performance'] = df['etest_p'] / df['Academic_Score']

# %%
df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  ...    salary  Degree_Category  MBA_Category  Academic_Score  \
# 0       0  ...  270000.0              Low           Low         68.7000
# 1       1  ...  200000.0             High        Medium         75.3550
# 2       0  ...  250000.0           Medium           Low         63.7000
# 3       0  ...  265000.0              Low           Low         54.8575
# 4       0  ...  425000.0           Medium           Low         72.0500
#
#    Placement_Readiness Consistency_Score Academic_Improvement  \
# 0             61.85000         72.000000                -9.00
# 1             80.92750         78.380000                -1.85
# 2             69.35000         65.666667                -1.00
# 3             60.42875         53.333333                -4.00
# 4             84.42500         77.566667               -12.50
#
#    MBA_Improvement  WorkEx_Flag  Test_Performance
# 0             0.80          NaN          0.800582
# 1           -11.20          NaN          1.147900
# 2            -6.20          NaN          1.177394
# 3             7.43          NaN          1.203117
# 4           -17.80          NaN          1.343511
#
# [5 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# sl_no                     0
# gender                    0
# ssc_p                     0
# ssc_b                     0
# hsc_p                     0
# hsc_b                     0
# hsc_s                     0
# degree_p                  0
# degree_t                  0
# workex                    0
# etest_p                   0
# specialisation            0
# mba_p                     0
# status                    0
# salary                    0
# Degree_Category           0
# MBA_Category              0
# Academic_Score            0
# Placement_Readiness       0
# Consistency_Score         0
# Academic_Improvement      0
# MBA_Improvement           0
# WorkEx_Flag             215
# Test_Performance          0
# dtype: int64

# %%
import joblib

joblib.dump(model, "placement_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 3
#       1 import joblib
#       2
# ----> 3 joblib.dump(model, "placement_model.pkl")
#
# NameError: name 'model' is not defined

# %%
mport joblib

joblib.dump(rf, "placement_model.pkl")
# Out:
#   Cell In[73], line 1
#     mport joblib
#           ^
# SyntaxError: invalid syntax

# %%
# %who
# Out:
# DecisionTreeClassifier	 KNeighborsClassifier	 LabelEncoder	 RandomForestClassifier	 X	 X_test	 X_train	 accuracy_score	 classification_report
# classifier	 confusion_matrix	 df	 df1	 dt	 encoder	 f1_score	 i	 i_val
# joblib	 knn	 loaded_knn	 np	 os	 pd	 plt	 rf	 sns
# train_test_split	 value	 y	 y_pred	 y_pred1	 y_pred2	 y_pred3	 y_test	 y_train

# %%
import joblib

joblib.dump(rf, "placement_model.pkl")
# Out:
# ['placement_model.pkl']

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'knn_placement_model.joblib',
#  'panda basics',
#  'placement.ipynb',
#  'Placement_data_full_class (1).csv',
#  'placement_model.pkl']

# %%
os.path.exists("placement_model.pkl")
# Out:
# True

# %%
X = df[['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p']]
y = df['status]

# %%
from sklearn.linear_model import LogisticRegression

# %%
import joblib
joblib.dump(model, 'placement_model.pkl')
print("Expected features:")
print(model.feature_names_in_)
